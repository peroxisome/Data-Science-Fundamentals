# %% [markdown]
# # Worksheet 02
#
# Name: Jou-Hsuan Lee
# UID: U15459646
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# It's hard to test the code until the final steps.

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# It's hard to know everything about the process, and might write some extra code.

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# 1. Keep your code simple.
# 2. Read the error message carfully.
# 3. Print out the intermediate results.
# 4. Take a rest.

# %% [markdown]
# d) Follow along with the live coding. You can write your code here:

# %%
class Board:
    def __init__(self):
        self.board = [["_" for _ in range(8)] for _ in range(8)] # list of list
        self.solutions = 0
    
    def __repr__(self):
        res = ""
        for row in self.board:
            for col in row:
                res += col + " "
            res += "\n"
        return res

    # three direction check
    def is_legal_row(self, row):
        for j in range(len(self.board[row])):
            if self.board[row][j] == "Q" :# improve: can add a new function is_queen()
                return False
        return True

    def is_legal_col(self, col):
        for i in range(len(self.board)):
            if self.board[i][col] == "Q":
                return False
        return True
    
    def is_legal_diag(self, row, col):
        for i in range(len(self.board)):
            if self.is_on_board(row-i, col-i) and self.board[row-i][col-i] == 'Q': 
                return False
            elif self.is_on_board(row-i, col+i) and self.board[row-i][col+i] == 'Q': 
                return False
            elif self.is_on_board(row+i, col+i) and self.board[row+i][col+i] == 'Q': 
                return False
            elif self.is_on_board(row+i, col-i) and self.board[row+i][col-i] == 'Q': 
                return False
        return True  
    
    def is_legal(self, row, col):
        if not self.is_legal_row(row):
            return False
        if not self.is_legal_col(col):
            return False
        if not self.is_legal_diag(row, col):
            return False
        return True
    
    def set_queen_at(self, row, col):
        self.board[row][col] = 'Q'

    def unset_queen_at(self, row):
        self.board[row] = ["_" for _ in range(8)]
        
    def is_on_board(self, row, col):
        return row >= 0 and row < 8 and col >=0 and col < 8
    
    def get_queen_on(self, row):
        for col in range(len(self.board[row])): # symetric
            if self.board[row][col] == 'Q':
                return col
        raise ValueError('programmer error')
        
    def search(self):
        row = 0
        col = 0
        self.solutions = 0
        while row >= 0:
            if row < 8:
                if self.is_legal(row, col):
                    self.set_queen_at(row, col)
                    row += 1
                    col = 0
                else:
                    col += 1
                    while col >= 8:
                        if row == 0:
                            return                        
                        col = self.get_queen_on(row-1)
                        self.unset_queen_at(row-1)
                        col += 1
                        row -= 1


            else:
                self.solutions += 1
                print("Solution " + str(self.solutions))
                print(self)
                col = self.get_queen_on(row-1)
                self.unset_queen_at(row-1)
                col += 1
                row -= 1
                if row == 0:
                    return
                elif col >= 8: # no queen can put on board, so go to previous row and go to the next col
                    col = self.get_queen_on(row-1)
                    self.unset_queen_at(row-1)
                    col += 1
                    row -= 1
                    if row == 0:
                        return

                

my_board = Board()
my_board.search()
print(my_board.solutions)
# Out:
# Solution 1
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# Solution 2
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Solution 3
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
#
# Solution 4
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# Solution 5
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
#
# Solution 6
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
#
# Solution 7
# _ Q _ _ _ _ _ _
# ...
